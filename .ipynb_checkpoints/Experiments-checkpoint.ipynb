# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
N_A=240000
N_P=98000
fact=4.4/25.
Koff_A = 3.24*10**(-3)
Koff_P = 7.19*10**(-3)
Kon_A = 6.29*10**(-3)*fact
Kon_P = 7.682*10**(-2)*fact

print Koff_A,Koff_P,Kon_A,Kon_P,K_AP,K_PA
# Out:
# 0.00324 0.00719 0.00110704 0.01352032 0.00176 1.76e-05

# %%
A=np.linspace(0,N_A,100000)
P=np.linspace(0,N_P,100000)
for i in range(3):
    for j in range(3):
        alpha=1+i
        beta=1+j
        K_AP = 1*10**(-3)*fact**(2*(1+alpha))
        K_PA = 1*10**(-3)*fact**(2*(1+beta))
        A_P=Kon_A*N_A/(Koff_A+Kon_A+K_AP*P**alpha)
        P_A=Kon_P*N_P/(Koff_P+Kon_P+K_PA*A_P**beta)
#plt.plot(P_A-Kon_P*N_P/(Koff_P+Kon_P+K_PA*A_P**beta))
        plt.plot(P-P_A)
        plt.xlim([0,3000])

# %% [markdown]
# ###

# %%
from scipy.optimize import fsolve
import math
alpha=1
beta=1
def equations(p):
    x, y = p
    return (Kon_A*N_A/(Koff_A+Kon_A+K_AP*y**alpha)-x, Kon_P*N_P/(Koff_P+Kon_P+K_PA*x**beta-y))

x, y =  fsolve(equations, (N_A, N_P))

print equations((x, y))
# Out:
# (2.5601212917536751e-124, -2.2470446423725927e-127)

# %%
from simpy import nsolve
nsolve([Kon_A*N_A/(Koff_A+Kon_A+K_AP*y**alpha)-x, Kon_P*N_P/(Koff_P+Kon_P+K_PA*x**beta)-y], [x, y], [1, 1])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-99-4ca9583ab09d> in <module>()
# ----> 1 from simpy import nsolve
#       2 nsolve([Kon_A*N_A/(Koff_A+Kon_A+K_AP*y**alpha)-x, Kon_P*N_P/(Koff_P+Kon_P+K_PA*x**beta)-y], [x, y], [1, 1])
#
# ImportError: No module named simpy

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
Z = np.sqrt(X**2 + Y**2)
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-444722426e14> in <module>()
#       2 fig = plt.figure()
#       3 ax = fig.add_subplot(111, projection='3d')
# ----> 4 Z = np.sqrt(X**2 + Y**2)
#       5 surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
#       6                        linewidth=0, antialiased=False)
#
# NameError: name 'X' is not defined

# %%
plt.plot(fig_size=(16,8))
plt.subplot(121)
plt.imshow(Z)
plt.subplot(122)
plt.contour(Z)

# %%
X = np.arange(-10, 10, 1)
Y = np.arange(-10, 10, 1)
X,Y= np.meshgrid(X, Y)

fig= plt.figure(figsize=(24,8))
ax=plt.subplot(131)
q = ax.quiver(X, Y, X, Y)
plt.xlim([-8,8])
plt.ylim([-8,8])
ax=plt.subplot(132)
q = ax.quiver(X, Y, -Y, X)
plt.xlim([-8,8])
plt.ylim([-8,8])
ax=plt.subplot(133)
q = ax.quiver(X, Y, X-Y, Y+X)
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.show()
